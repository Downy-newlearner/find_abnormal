# %% [markdown]
# 61: Model.Suffix_AutoClave:
# nunique: 7
# ['AJX75334505' 'AJX75334501' 'AJX75334502' 'AJX75334507' 'AJX75334506'
#  'AJX75334508' 'AJX75334503']
# Model.Suffix_AutoClave has no missing values
#
# 62: Workorder_AutoClave:
# nunique: 663
# ['4F1XA938-1' '3KPM0016-2' '4E1X9167-1' '3K1X0057-1' '3HPM0007-1'
#  '3G1X9017-1' '4BPXX078-0001' '3K1XA497-1' '4B1XD470-1' '4A1XA635-1'
#  '4BPM0210-1' '3H1X8429-1' '4E1XC442-1' '4C1XJ020-1' '3G1XB045-1'
#  (중략)
#  '3J1XG645-1' '3G1X8647-2' '3H1XC430-1' '3H1XB714-1' '4CPM0074-1'
#  '3K1X9887-2' '3L1XB234-1' '3HPM0061-1']
# Workorder_AutoClave has no missing values
#
# 63: 1st Pressure Collect Result_AutoClave:
# nunique: 27
# [0.312 0.311 0.315 0.299 0.302 0.316 0.31  0.313 0.303 0.308 0.309 0.304
#  0.3   0.301 0.314 0.305 0.307 0.306 0.297 0.298 0.319 0.317 0.318 0.29
#  0.292 0.295 0.296]
# 1st Pressure Collect Result_AutoClave has no missing values
#
# 64: 1st Pressure 1st Pressure Unit Time_AutoClave:
# nunique: 9
# [240 241 300 181 180   1  61   0  60]
# 1st Pressure 1st Pressure Unit Time_AutoClave has no missing values
#
# 65: 2nd Pressure Collect Result_AutoClave:
# nunique: 67
# [0.493 0.311 0.49  0.3   0.302 0.501 0.492 0.314 0.491 0.303 0.317 0.304
#  0.316 0.581 0.58  0.5   0.498 0.301 0.312 0.499 0.582 0.307 0.313 0.309
#  0.299 0.305 0.599 0.315 0.306 0.502 0.32  0.31  0.583 0.319 0.308 0.354
#  0.318 0.349 0.298 0.503 0.361 0.62  0.9   0.359 0.497 0.621 0.352 0.362
#  0.496 0.35  0.323 0.357 0.351 0.358 0.355 0.36  0.321 0.356 0.715 0.353
#  0.395 0.803 0.452 0.806 0.364 0.297 0.322]
# 2nd Pressure Collect Result_AutoClave has no missing values
#
# 66: 2nd Pressure Unit Time_AutoClave:
# nunique: 10
# [  1 121 120  90  60   0 150 181  61 180]
# 2nd Pressure Unit Time_AutoClave has no missing values
#
# 67: 3rd Pressure Collect Result_AutoClave:
# nunique: 67
# [0.499 0.498 0.5   0.501 0.598 0.497 0.597 0.6   0.549 0.496 0.495 0.502
#  0.599 0.55  0.596 0.402 0.354 0.503 0.406 0.548 0.547 0.504 0.349 0.404
#  0.361 0.674 0.914 0.358 0.675 0.351 0.613 0.611 0.359 0.546 0.355 0.621
#  0.362 0.407 0.601 0.35  0.551 0.356 0.627 0.357 0.353 0.305 0.505 0.403
#  0.61  0.36  0.352 0.761 0.401 0.397 0.408 0.698 0.552 0.823 0.451 0.612
#  0.315 0.824 0.405 0.614 0.506 0.364 0.312]
# 3rd Pressure Collect Result_AutoClave has no missing values
#
# 68: 3rd Pressure Unit Time_AutoClave:
# nunique: 11
# [120 121 150  90 181 180  61 301  60 241   1]
# 3rd Pressure Unit Time_AutoClave has no missing values
#
# 69: Chamber Temp. Collect Result_AutoClave:
# nunique: 26
# [54 56 47 52 53 51 49 50 48 55 57 46 45 32 58 44 43 59 36 33 35 37 40 34
#  38 42]
# Chamber Temp. Collect Result_AutoClave has no missing values
#
# 70: Chamber Temp. Unit Time_AutoClave:
# nunique: 24
# [361 483 363 480 481 452 510 360 450 362 512 540 212 303 183 300 423 301
#   61 243 180   3 121 242]
# Chamber Temp. Unit Time_AutoClave has no missing values
#
# 71: Chamber Temp. Judge Value_AutoClave:
# nunique: 2
# ['OK' 'NG']
# Chamber Temp. Judge Value_AutoClave has no missing values

# %% [markdown]
# Chamber Temp. Judge Value_AutoClave에 따른 분석
#
# OK일 때는 온도가 50~60도 사이에 분포하고, NG일 때는 45~49도 사이에 분포한다.
#
# 1. OK일 때
#     Chamber Temp. Collect Result_AutoClave
#     54    8427
#     50    5652
#     53    5342
#     55    3282
#     52    2081
#     56    1699
#     51    1478
#     57     951
#     58     102
#     36      32
#     32      23
#     43      14
#     37       6
#     38       6
#     59       4
#     33       4
#     35       4
#     40       3
#     34       2
#
# 2. NG일 때
#     49    5836
#     48    3347
#     47    1787
#     46     376
#     45      37
#     43       6
#     44       3
#     36       1
#     42       1
